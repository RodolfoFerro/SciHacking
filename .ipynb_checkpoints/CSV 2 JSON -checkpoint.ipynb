# %%
import numpy as np
import pandas as pd

file = pd.read_csv("data1.csv", ",", encoding="latin_1")
df = pd.DataFrame(file)
df.head()
# Out:
#   NOBILIS APELLIDO PATERNO APELLIDO MATERNO          NOMBRE NIVEL  AREA  \
# 0     DR.           MORENO          DE ALBA  JOSE GUADALUPE     3     4
# 1     DR.          PASCUAL             BUXO            JOSE     3     4
# 2     DR.            VERMA          JAISWAL    SURENDRA PAL     3     1
# 3     DR.           ALONSO          SANCHEZ           JORGE     3     4
# 4    DRA.           AZAOLA          GARRIDO           ELENA     3     4
#
#                                 CAMPO  \
# 0                        LINGíìISTICA
# 1                      ARTES Y LETRAS
# 2  CIENCIAS DE LA TIERRA Y DEL COSMOS
# 3                        ANTROPOLOGIA
# 4                        ANTROPOLOGIA
#
#                                         DISCIPLINA SUBDISCIPLINA  \
# 0                                              NaN           NaN
# 1           TEORIA,  ANALISIS Y CRITICA LITERARIOS           NaN
# 2                                       GEOQUIMICA         OTROS
# ...

# %%
N_campos = 0
campos = []
for campo in
# Out:
# 0                               LINGíìISTICA
# 1                             ARTES Y LETRAS
# 2         CIENCIAS DE LA TIERRA Y DEL COSMOS
# 3                               ANTROPOLOGIA
# 4                               ANTROPOLOGIA
# 5                        CIENCIAS DE LA VIDA
# 6                        CIENCIAS DE LA VIDA
# 7                        CIENCIAS DE LA VIDA
# 8                                     FISICA
# 9                                     FISICA
# 10                                    FISICA
# 11                 CIENCIAS DE LA TECNOLOGIA
# 12                 CIENCIAS DE LA TECNOLOGIA
# 13                 CIENCIAS DE LA TECNOLOGIA
# 14                 CIENCIAS DE LA TECNOLOGIA
# 15                 CIENCIAS DE LA TECNOLOGIA
# 16                                    FISICA
# 17                                    FISICA
# 18                        CIENCIAS POLITICAS
# 19                                SOCIOLOGIA
# 20                                    FISICA
# ...
